# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#%matplotlib inline

import sklearn as skl
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE


df = pd.read_csv('data/MIMICtable.csv')
df
# Out:
#         bloc  icustayid   charttime  gender      age  elixhauser  \
# 0          1          3  7245486000       0  17639.0           0
# 1          2          3  7245500400       0  17639.0           0
# 2          3          3  7245514800       0  17639.0           0
# 3          4          3  7245529200       0  17639.0           0
# 4          5          3  7245543600       0  17639.0           0
# ...      ...        ...         ...     ...      ...         ...
# 266665     8      99995  4612892400       0   8538.0           0
# 266666     9      99995  4612906800       0   8538.0           0
# 266667    10      99995  4612921200       0   8538.0           0
# 266668    11      99995  4612935600       0   8538.0           0
# 266669    12      99995  4612950000       0   8538.0           0
#
#         re_admission  died_in_hosp  died_within_48h_of_out_time  \
# 0                  0             0                            0
# 1                  0             0                            0
# 2                  0             0                            0
# 3                  0             0                            0
# 4                  0             0                            0
# ...              ...           ...                          ...
# 266665             0             0                            0
# 266666             0             0                            0
# 266667             0             0                            0
# 266668             0             0                            0
# 266669             0             0                            0
#
#         mortality_90d  ...   PaO2_FiO2  median_dose_vaso  max_dose_vaso  \
# 0                   1  ...  240.000004               0.0            0.0
# 1                   1  ...  240.000004               0.0            0.0
# 2                   1  ...  240.000004               0.0            0.0
# 3                   1  ...  240.000004               0.0            0.0
# 4                   1  ...  240.000004               0.0            0.0
# ...               ...  ...         ...               ...            ...
# 266665              0  ...  424.380952               0.0            0.0
# 266666              0  ...  424.380952               0.0            0.0
# 266667              0  ...  424.380952               0.0            0.0
# 266668              0  ...  424.380952               0.0            0.0
# 266669              0  ...  424.380952               0.0            0.0
#
#         input_total  input_4hourly  output_total  output_4hourly  \
# 0          6527.000           50.0       13617.0           520.0
# 1          6577.000           50.0       13982.0           365.0
# 2          6627.000           50.0       14262.0           280.0
# 3          6677.000           50.0       14602.0           340.0
# 4          6727.000           50.0       15142.0           540.0
# ...             ...            ...           ...             ...
# 266665     2633.583            0.0        6310.0           400.0
# 266666     2633.583            0.0        7010.0           700.0
# 266667     2633.583            0.0        7430.0           420.0
# 266668     2633.583            0.0        7430.0             0.0
# 266669     2633.583            0.0        7950.0           520.0
#
#         cumulated_balance  SOFA  SIRS
# 0               -7090.000     5     2
# 1               -7405.000     5     2
# 2               -7635.000     5     2
# 3               -7925.000     5     1
# 4               -8415.000     5     2
# ...                   ...   ...   ...
# 266665          -3676.417     0     2
# 266666          -4376.417     0     2
# 266667          -4796.417     0     1
# 266668          -4796.417     4     1
# 266669          -5316.417     0     2
#
# [266670 rows x 59 columns]

# %%
print(df.columns)

print(f'mimic data shape: {df.shape}')

num_icu_stays = len(np.unique(df.icustayid))
print(f'total # of icu stays: {num_icu_stays}')

stays = {} # {3: [1235, 1237, 1238], ...}
for idx, time in zip(df.icustayid, df.charttime):
    stays.setdefault(idx, [])
    stays[idx].append(time)
# Out:
# Index(['bloc', 'icustayid', 'charttime', 'gender', 'age', 'elixhauser',
#        're_admission', 'died_in_hosp', 'died_within_48h_of_out_time',
#        'mortality_90d', 'delay_end_of_record_and_discharge_or_death',
#        'Weight_kg', 'GCS', 'HR', 'SysBP', 'MeanBP', 'DiaBP', 'RR', 'SpO2',
#        'Temp_C', 'FiO2_1', 'Potassium', 'Sodium', 'Chloride', 'Glucose', 'BUN',
#        'Creatinine', 'Magnesium', 'Calcium', 'Ionised_Ca', 'CO2_mEqL', 'SGOT',
#        'SGPT', 'Total_bili', 'Albumin', 'Hb', 'WBC_count', 'Platelets_count',
#        'PTT', 'PT', 'INR', 'Arterial_pH', 'paO2', 'paCO2', 'Arterial_BE',
#        'Arterial_lactate', 'HCO3', 'mechvent', 'Shock_Index', 'PaO2_FiO2',
#        'median_dose_vaso', 'max_dose_vaso', 'input_total', 'input_4hourly',
#        'output_total', 'output_4hourly', 'cumulated_balance', 'SOFA', 'SIRS'],
#       dtype='object')
# mimic data shape: (266670, 59)
# total # of icu stays: 20496

# %%
num_time_points_per_stay = [len(times) for times in stays.values()]
print(f'avg # of time points per icu stay: {np.mean(num_time_points_per_stay)}')
sns.histplot(num_time_points_per_stay)
plt.xlabel('# of time points per icu stay')
# Out:
# avg # of time points per icu stay: 13.010831381733022
# Text(0.5, 0, '# of time points per icu stay')

# %%
duration_per_stay = [(times[-1] - times[0]) for times in stays.values()]
print(f'avg duration of an icu stay (s): {np.mean(duration_per_stay)}')
sns.histplot(duration_per_stay)
plt.xlabel('duration per icu stay (s)')
# Out:
# avg duration of an icu stay (s): 176905.85480093677
# Text(0.5, 0, 'duration per icu stay (s)')

# %%
# average number of stays per person

# %%
# t-sne (maybe also pca)
